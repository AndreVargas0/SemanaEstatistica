# %% [markdown]
# ## Aula 1

# %%
! pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/imigrantes_canada.csv')

# %%
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
# ...

# %% [markdown]
# Coluna País

# %%
df['País']
# Out:
# 0          Afeganistão
# 1              Albânia
# 2              Argélia
# 3      Samoa Americana
# 4              Andorra
#             ...
# 190             Vietnã
# 191    Saara Ocidental
# 192              Iémen
# 193             Zâmbia
# 194           Zimbábue
# Name: País, Length: 195, dtype: object

# %%
df.set_index('País',inplace=True)

# %%
anos = list(map(str,range(1980,2014)))

# %%
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
brasil = df.loc['Brasil',anos]

# %%
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %%
print(type(brasil))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### pandas = series e dataframes
# ### list, tupla, dict

# %%
brasil_dict={'ano':brasil.index.tolist(),'imigrantes':brasil.values.tolist()}

# %%
dados_brasil= pd.DataFrame(brasil_dict)

# %%
dados_brasil
# Out:
#      ano  imigrantes
# 0   1980         211
# 1   1981         220
# 2   1982         192
# 3   1983         139
# 4   1984         145
# 5   1985         130
# 6   1986         205
# 7   1987         244
# 8   1988         394
# 9   1989         650
# 10  1990         650
# 11  1991         877
# 12  1992        1066
# 13  1993         866
# 14  1994         566
# 15  1995         572
# 16  1996         586
# 17  1997         591
# 18  1998         531
# 19  1999         626
# 20  2000         845
# 21  2001         847
# 22  2002         745
# 23  2003         839
# 24  2004         917
# 25  2005         969
# 26  2006        1181
# 27  2007        1746
# 28  2008        2138
# 29  2009        2509
# 30  2010        2598
# 31  2011        1508
# 32  2012        1642
# 33  2013        1714

# %% [markdown]
# Gráfico de Linha

# %%
! pip install matplotlib

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# %% [markdown]
# 1 polegada = 2.54
# Largura = 8pol/20.32cm/800px-dpi
# Altura = 4pol/10.16cm/400px-dpi

# %%
plt.figure(figsize=(8,4))
plt.plot(dados_brasil['ano'],dados_brasil['imigrantes'])
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.grid()
plt.yticks([500,1000,1500,2500,3000])
plt.show()

# %% [markdown]
# ## Aula 2

# %%
plt.figure(figsize=(8,4))
plt.plot(dados_brasil['ano'],dados_brasil['imigrantes'])
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.yticks([500,1000,1500,2500,3000])
plt.grid()
plt.title('Imigração de brasileiros para o Canadá')
plt.xlabel('Anos')
plt.ylabel('Números de imigrantes')
plt.show()

# %%
fig,axs = plt.subplots(1,2,figsize=(15,4))

#Subplot 1: Gráfico de linha
axs[0].plot(dados_brasil['ano'],dados_brasil['imigrantes'], markersize=3, marker='o',color='black')
axs[0].xaxis.set_major_locator(MultipleLocator(5))
axs[0].set_xlabel('Anos')
axs[0].set_ylabel('Número de imigrantes')
axs[0].set_title("Gráfico de linha imigração do Brasil para o Canadá")
axs[0].fill_between(dados_brasil['ano'], dados_brasil['imigrantes'], color='grey', alpha=1)
axs[0].grid()

#Subplot 2: Gráfico boxplot
axs[1].violinplot(dados_brasil['imigrantes'])
axs[1].set_title("Boxplot da imigração do Brasil para o Canadá")
axs[1].set_xlabel('Brasíl')
axs[1].set_ylabel('Número de imigrantes')
axs[1].grid()
plt.show()

# %% [markdown]
# ### Comparativo de imigração para o Canadá,com os países Brasil, Colombia, Argentina e Peru

# %%
# Criar uma figura
fig, axs = plt.subplots(2,2,figsize=(10,6))
fig.subplots_adjust(hspace=0.5,wspace=0.3)

#subplot

#Brasil
axs[0,0].plot(df.loc['Brasil',anos])
axs[0,0].set_title('Brasil')

#Colombia
axs[0,1].plot(df.loc['Colômbia',anos])
axs[0,1].set_title('Colômbia')

#Argentina
axs[1,0].plot(df.loc['Argentina',anos])
axs[1,0].set_title('Argentina')

#Peru
axs[1,1].plot(df.loc['Peru',anos])
axs[1,1].set_title('Peru')

for ax in axs.flat:
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# %% [markdown]
# # Aula 3

# %%
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

# %%
america_sul = df.query('Região == "América do Sul" ')

# %%
america_sul
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
# Equador    América Latina e o Caribe  América do Sul   238   207   184   155
# Guiana     América Latina e o Caribe  América do Sul  2334  2943  3575  2650
# Paraguai   América Latina e o Caribe  América do Sul    45    26    32    40
# Peru       América Latina e o Caribe  América do Sul   317   456   401   241
# Suriname   América Latina e o Caribe  América do Sul    15    10    21    12
# Uruguai    América Latina e o Caribe  América do Sul   128   132   146   105
# ...

# %%
america_sul.index
# Out:
# Index(['Argentina', 'Bolívia', 'Brasil', 'Chile', 'Colômbia', 'Equador',
#        'Guiana', 'Paraguai', 'Peru', 'Suriname', 'Uruguai', 'Venezuela'],
#       dtype='object', name='País')

# %%
america_sul['Total']
# Out:
# País
# Argentina    19596
# Bolívia       3205
# Brasil       29659
# Chile        21359
# Colômbia     72088
# Equador      12233
# Guiana       75785
# Paraguai      1944
# Peru         32652
# Suriname       739
# Uruguai       4715
# Venezuela    21267
# Name: Total, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12, 5))
ax.bar(america_sul.index, america_sul['Total'], color=cores)
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013',fontsize=18)
ax.set_ylabel('Número de imigrantes', fontsize=14)
ax.set_xlabel('')
ax.yaxis.set_tick_params(labelsize=10)
ax.xaxis.set_tick_params(labelsize=10)
plt.show()

# %% [markdown]
# # Aula 4

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize=(12, 5))
ax.barh(america_sul.index, america_sul['Total'], color=cores)
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013',fontsize=18)
ax.set_ylabel('Número de imigrantes', fontsize=14)
ax.set_xlabel('')
ax.grid()
bars = ax.barh(america_sul.index, america_sul['Total'], color=cores, edgecolor='black', height=0.6)
for bar in bars:
    width = bar.get_width()
    ax.text(width + 0.02 * width, bar.get_y() + bar.get_height() / 2,
            f'{width:.0f}', va='center', ha='left', fontsize=10, color='black')
ax.yaxis.set_tick_params(labelsize=10)
ax.xaxis.set_tick_params(labelsize=10)
plt.show()

# %%
sns.set(style='whitegrid')
fig, ax = plt.subplots(figsize=(12, 7)) 
bars = ax.barh(america_sul.index, america_sul['Total'], color=cores, edgecolor='black', height=0.6)
for bar in bars:
    width = bar.get_width()
    ax.text(width + 0.02 * width, bar.get_y() + bar.get_height() / 2,
            f'{width:.0f}', va='center', ha='left', fontsize=10, color='black')
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', fontsize=18)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %%
america_sul_sorted = america_sul.sort_values('Total',ascending=True)
america_sul_sorted.head()
# Out:
#                          Continente          Região  1980  1981  1982  1983  \
# País
# Suriname  América Latina e o Caribe  América do Sul    15    10    21    12
# Paraguai  América Latina e o Caribe  América do Sul    45    26    32    40
# Bolívia   América Latina e o Caribe  América do Sul    44    52    42    49
# Uruguai   América Latina e o Caribe  América do Sul   128   132   146   105
# Equador   América Latina e o Caribe  América do Sul   238   207   184   155
#
#           1984  1985  1986  1987  ...  2005  2006  2007  2008  2009  2010  \
# País                              ...
# Suriname     5    16     7    46  ...    15    16    20     9    12    13
# Paraguai    48    36    34    72  ...    75    88    98    95    88    89
# Bolívia     38    44    79   165  ...   134   139   107   143   214   180
# Uruguai     90    92   137   269  ...   217   175   147   160    99    93
# Equador    179   208   240   344  ...   491   525   419   437   373   353
#
# ...

# %%
sns.set(style='whitegrid')
fig, ax = plt.subplots(figsize=(12, 7)) 
bars = ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores, edgecolor='black', height=0.6)
for bar in bars:
    width = bar.get_width()
    ax.text(width + 0.02 * width, bar.get_y() + bar.get_height() / 2,
            f'{width:.0f}', va='center', ha='left', fontsize=10, color='black')
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', fontsize=18)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %%
cores2 = ['#28A745' if pais == 'Brasil' else '#B0B0B0' for pais in america_sul_sorted.index]
sns.set(style='whitegrid')
fig, ax = plt.subplots(figsize=(12, 7)) 
bars = ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores2, edgecolor='black', height=0.6)
for bar in bars:
    width = bar.get_width()
    ax.text(width + 0.02 * width, bar.get_y() + bar.get_height() / 2,
            f'{width:.0f}', va='center', ha='left', fontsize=10, color='black')
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', fontsize=18)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()
